# %% [markdown]
# # Demo Convolutional Neural Network (CNN) para procesar imágenes e identificar TIPOS de ANIMALES

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
import keras
from keras.layers import Input, Dense
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Reshape, Flatten, Dropout
from keras.models import Model
from keras.utils import plot_model

from sklearn.model_selection import train_test_split
from keras.utils import np_utils

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Definir los parámetros:

# %%
## selección de los parámetros 

# 
#@markdown ### Parámetros de imágenes:
imagen_largo_ancho =  64#@param {type:"integer"}
imagen_color = True #@param {type:"boolean"}
imagen_usar_generadas_data_augmentation = True #@param {type:"boolean"}

#@markdown ### Parámetros de la red:
cnn_tamaño_kernel =  3#@param {type:"integer"}
cnn_tamaño_pooling = 2 #@param {type:"integer"}
cnn_cantidad_capas_ocultas =  4#@param {type:"integer"}
cnn_cantidad_neuronas_Dense = 64 #@param {type:"integer"}
cnn_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
cnn_cant_epocas_entrenamiento =  250#@param {type:"integer"}


## aplicación de los parámetros elegidos

# tamaño de las imágenes
if imagen_largo_ancho<=10:
  imagen_largo_ancho = 10
IMAGE_SHAPE = (imagen_largo_ancho, imagen_largo_ancho, (3 if imagen_color else 1))

# indica si se usan las imágenes generadas por data augmentation
usarDA = imagen_usar_generadas_data_augmentation

# tamaño de los kernels y pooling (para simplificar son todas iguales)
if cnn_tamaño_kernel<1:
  cnn_tamaño_kernel = 1
cnn_kernel_shape = (cnn_tamaño_kernel, cnn_tamaño_kernel)
if cnn_tamaño_pooling<1:
  cnn_tamaño_pooling=1
cnn_pooling_shape = (cnn_tamaño_pooling, cnn_tamaño_pooling)

# indica la configuración para la parte Encoder 
#   (cada elemento de las listas son la configuración de las capas Conv)
#cnn_filters = [ 128, 64, 32, 16, 8 ] 
if cnn_cantidad_capas_ocultas<1:
  cnn_cantidad_capas_ocultas = 1
cnn_filters = []
for i in range(cnn_cantidad_capas_ocultas, 0, -1):
  cnn_filters.append( 2**(i+2) )

# define tamaño de capa densa previa a la de salida
num_Dense_out = (8 if cnn_cantidad_neuronas_Dense<1 else cnn_cantidad_neuronas_Dense)

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (cnn_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if cnn_cant_epocas_entrenamiento<1 else cnn_cant_epocas_entrenamiento)

print("Configuración de la CNN definida: ")
print ("     -Tamaño Imagen: ", IMAGE_SHAPE)
print ("     -Kernels + Pooling: [", cnn_kernel_shape, "+", cnn_pooling_shape, "] ")
print ("     -Capas: [ ", IMAGE_SHAPE, ", Conv", cnn_filters,  ", FLATTEN, Dense[", num_Dense_out, "], DROP-OUT, ", ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Configuración de la CNN definida:
#      -Tamaño Imagen:  (64, 64, 3)
#      -Kernels + Pooling: [ (3, 3) + (2, 2) ]
#      -Capas: [  (64, 64, 3) , Conv [64, 32, 16, 8] , FLATTEN, Dense[ 64 ], DROP-OUT,  Softmax

# %% [markdown]
# 3) Montar el Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/IA/demo ANIMALES/imagenes' #@param {type:"string"}
path_entrenamiento = '/train'  #@param {type:"string"}
path_prueba = '/test'  #@param {type:"string"}

imagPath_train = path + path_entrenamiento
imagPath_test = path + path_prueba
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo:

# %%
#@title Cargar imágenes
# define función para cargar las imágenes
def cargarImagenes(imagPath):
  classes_ori = [] 
  images_ori = []
  esDA_ori = []

  all_dirs = os.listdir( imagPath )
  for each_dir in all_dirs:

      auxiPath = imagPath + '/' + each_dir 
      imagFN  = os.listdir( auxiPath )
      for each_imagFN in imagFN:

            esImagDA = (each_imagFN[:2] == 'da')
            
            if usarDA or (not esImagDA): 
                
                # abre la imagen
                imag = Image.open(auxiPath + "/" + each_imagFN)
                
                # ajusta el tamaño
                if IMAGE_SHAPE[2]==1:              
                  tipoImage = 'L'
                else:                
                  tipoImage = 'RGB'
                imag = imag.convert(tipoImage)
                imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.ANTIALIAS)          
                
                # transforma a un vector de nros
                arImag = np.array(imag)
                
                # agrega a los vectores
                classes_ori.append( each_dir )
                images_ori.append( arImag )
                esDA_ori.append( esImagDA )

  return classes_ori, images_ori, esDA_ori, tipoImage

# carga las imagenes de entrenamiento
classes_train, images_train, esDAimag_train, tipoImage_train = cargarImagenes(imagPath_train)
print("> Para Entrenamiento: ")
print("- Clases cargadas: ", len(classes_train))
print("- Imágenes cargadas: ", len(classes_train))

if len(classes_train)>0:
  print("- Ejemplo ", classes_train[0], " ", images_train[0].shape, ": ")
  display( Image.fromarray(images_train[0], tipoImage_train) )

# carga las imagenes de prueba
classes_test, images_test, esDAimag_test, tipoImage_test = cargarImagenes(imagPath_test)
print("\n\n> Para Prueba: ")
print("- Clases cargadas: ", len(classes_test))
print("- Imágenes cargadas: ", len(images_test))

if len(classes_test)>0:
  print("- Ejemplo ", classes_test[0], " ", images_test[0].shape, ": ")
  display( Image.fromarray(images_test[0], tipoImage_test) )
# Out:
# > Para Entrenamiento:
# - Clases cargadas:  102
# - Imágenes cargadas:  102
# - Ejemplo  mamifero   (64, 64, 3) :
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F1D000595F8>
# > Para Prueba:
# - Clases cargadas:  60
# - Imágenes cargadas:  60
# - Ejemplo  ave   (64, 64, 3) :
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F1D00059C18>

# %%
#@title Preparar imágenes
# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8))
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):    
  auxiAr = np.array(imagList).astype('float32') / 255.
  auxiAr = auxiAr.reshape((len(auxiAr), IMAGE_SHAPE[0], IMAGE_SHAPE[1], IMAGE_SHAPE[2]))  
  return auxiAr
  
# define función auxiliar para preparar lista de clases 
def prepare_clasesList(classesList, dictMapeo=None):
  if dictMapeo==None:
    # genera diccionario de mapeo
    auxDict = list(set(classesList))
    dictMapeo = dict( zip( auxDict, range(len(auxDict)) ) )
  # realiza el mapeo
  y = []
  for cl in classesList:
      y.append( dictMapeo[cl] )
  # convierte valores numéricos a columnas de vakores binarios (i.e. one hot encoded)
  dummy_y = np_utils.to_categorical(y)
  # devuelve
  return np.array(y), np.array(dummy_y), dictMapeo

# define vector auxiliar de datos de entrada para usar en el entrenamiento y prueba
x_train = prepare_imageList(images_train)
x_test = prepare_imageList(images_test)

# define vector auxiliar de datos de salida para usar en el entrenamiento y prueba
# también usa esta información para determinar la cantida de neuronas de salida
y_train, y_trainEnc, dictMapeo = prepare_clasesList(classes_train)
y_test, y_testEnc,_ = prepare_clasesList(classes_test, dictMapeo)

# genera diccionario auxiliar para poder convertir de ID de clase a nombre de clase
clases_map = [ x for x,y in dictMapeo.items() ]

print("> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
if tipo_output_softMax:
  print(" - y_trainEnc (cant): ", len(y_trainEnc))
else:
  print(" - y_train (cant): ", len(y_train))
print("\n\n> Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
if tipo_output_softMax:
  print(" - y_testEnc (cant): ", len(y_testEnc))
else:
  print(" - y_test (cant): ", len(y_test))
print("\n\n> Para Ambos: ")
print(" - dictMapeo: ", dictMapeo)
print(" - clases_map: ", clases_map)
if len(y_train)>0:
  print("\n - Imagen reconstruida de ", clases_map[y_train[0]],  "(", y_train[0], " / ", y_trainEnc[0], ")")
  plot_image(x_train[0])
# Out:
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (102, 64, 64, 3)
#  - y_trainEnc (cant):  102
#
#
# > Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (60, 64, 64, 3)
#  - y_testEnc (cant):  60
#
#
# > Para Ambos:
#  - dictMapeo:  {'ave': 0, 'reptil': 1, 'mamifero': 2, 'invertebrado': 3, 'insecto': 4, 'pez': 5}
#  - clases_map:  ['ave', 'reptil', 'mamifero', 'invertebrado', 'insecto', 'pez']
#
#  - Imagen reconstruida de  mamifero ( 2  /  [0. 0. 1. 0. 0. 0.] )

# %% [markdown]
# 5) Establecer el modelo para la CNN:

# %%
#@title Establecer modelo

# define la arquitectura de capas de la CNN
# teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=IMAGE_SHAPE, name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'conv_'
for i in range(len(cnn_filters)):  

    # define el nombre de la capa oculta
    auxlayerName = 'conv_'+str(i+1)

    # agrega las capas ocultas de tipo Conv2D + MaxPooling 
    eachLay = Conv2D(cnn_filters[i], cnn_kernel_shape, activation='relu', padding='same', name='c_'+auxlayerName)(eachLay) 
    eachLay = MaxPooling2D(cnn_pooling_shape, padding='same', name='p_'+auxlayerName)(eachLay)

#  agrega capa Flatten y Dense 
eachLay = Flatten(name='flat_'+auxlayerName)(eachLay)
eachLay = Dense(num_Dense_out, activation='relu', name='d_'+auxlayerName)(eachLay)
##eachLay = Dropout(0.5)(eachLay)

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(dictMapeo), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida

# genera el modelo Deep Autoencoder
model = Model(input_img_Lay, output_img_Lay, name='ConvNet')
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

print("Modelo CNN creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo CNN creado con  12  capas:
# Model: "ConvNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_img (InputLayer)       [(None, 64, 64, 3)]       0
# _________________________________________________________________
# c_conv_1 (Conv2D)            (None, 64, 64, 64)        1792
# _________________________________________________________________
# p_conv_1 (MaxPooling2D)      (None, 32, 32, 64)        0
# _________________________________________________________________
# c_conv_2 (Conv2D)            (None, 32, 32, 32)        18464
# _________________________________________________________________
# p_conv_2 (MaxPooling2D)      (None, 16, 16, 32)        0
# _________________________________________________________________
# c_conv_3 (Conv2D)            (None, 16, 16, 16)        4624
# _________________________________________________________________
# p_conv_3 (MaxPooling2D)      (None, 8, 8, 16)          0
# _________________________________________________________________
# c_conv_4 (Conv2D)            (None, 8, 8, 8)           1160
# _________________________________________________________________
# p_conv_4 (MaxPooling2D)      (None, 4, 4, 8)           0
# _________________________________________________________________
# flat_conv_4 (Flatten)        (None, 128)               0
# _________________________________________________________________
# d_conv_4 (Dense)             (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 6)                 390
# =================================================================
# Total params: 34,686
# Trainable params: 34,686
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 6) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(x_train, 
                                       (y_trainEnc if 

tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,),
          shuffle=True ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  102 ejemplos de entrenamiento:
#             se usan  91 ejemplos para entrenar
#             y  11 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/250
# 3/3 [==============================] - 1s 172ms/step - loss: 1.8031 - accuracy: 0.1209 - val_loss: 1.7903 - val_accuracy: 0.0909
# Epoch 2/250
# 3/3 [==============================] - 0s 19ms/step - loss: 1.7882 - accuracy: 0.1758 - val_loss: 1.7924 - val_accuracy: 0.0909
# Epoch 3/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.7811 - accuracy: 0.2418 - val_loss: 1.7869 - val_accuracy: 0.1818
# Epoch 4/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.7705 - accuracy: 0.3736 - val_loss: 1.7843 - val_accuracy: 0.0909
# Epoch 5/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.7565 - accuracy: 0.4176 - val_loss: 1.7799 - val_accuracy: 0.0909
# Epoch 6/250
# 3/3 [==============================] - 0s 16ms/step - loss: 1.7382 - accuracy: 0.4505 - val_loss: 1.7688 - val_accuracy: 0.0000e+00
# Epoch 7/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.7072 - accuracy: 0.5055 - val_loss: 1.7597 - val_accuracy: 0.0000e+00
# Epoch 8/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.6664 - accuracy: 0.4615 - val_loss: 1.7351 - val_accuracy: 0.0909
# Epoch 9/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.6039 - accuracy: 0.5275 - val_loss: 1.7163 - val_accuracy: 0.0909
# Epoch 10/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.5156 - accuracy: 0.4615 - val_loss: 1.6774 - val_accuracy: 0.2727
# Epoch 11/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.4012 - accuracy: 0.5604 - val_loss: 1.5880 - val_accuracy: 0.2727
# Epoch 12/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2927 - accuracy: 0.5495 - val_loss: 1.6227 - val_accuracy: 0.2727
# Epoch 13/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1900 - accuracy: 0.5824 - val_loss: 1.6766 - val_accuracy: 0.3636
# Epoch 14/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0543 - accuracy: 0.6484 - val_loss: 1.6411 - val_accuracy: 0.2727
# Epoch 15/250
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9684 - accuracy: 0.6923 - val_loss: 1.6764 - val_accuracy: 0.3636
# Epoch 16/250
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8911 - accuracy: 0.6923 - val_loss: 1.6662 - val_accuracy: 0.3636
# Epoch 17/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8354 - accuracy: 0.6923 - val_loss: 1.7212 - val_accuracy: 0.3636
# Epoch 18/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7654 - accuracy: 0.7363 - val_loss: 1.5238 - val_accuracy: 0.3636
# Epoch 19/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6186 - accuracy: 0.8352 - val_loss: 1.7588 - val_accuracy: 0.3636
# Epoch 20/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6238 - accuracy: 0.7802 - val_loss: 1.6450 - val_accuracy: 0.3636
# Epoch 21/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5021 - accuracy: 0.8462 - val_loss: 1.8089 - val_accuracy: 0.3636
# Epoch 22/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4308 - accuracy: 0.8681 - val_loss: 1.6206 - val_accuracy: 0.3636
# Epoch 23/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3618 - accuracy: 0.9121 - val_loss: 1.6192 - val_accuracy: 0.4545
# Epoch 24/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2949 - accuracy: 0.9451 - val_loss: 1.6750 - val_accuracy: 0.4545
# Epoch 25/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2404 - accuracy: 0.9670 - val_loss: 1.7040 - val_accuracy: 0.5455
# Epoch 26/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1945 - accuracy: 0.9780 - val_loss: 1.7099 - val_accuracy: 0.4545
# Epoch 27/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1337 - accuracy: 0.9890 - val_loss: 1.7515 - val_accuracy: 0.5455
# Epoch 28/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1127 - accuracy: 1.0000 - val_loss: 1.8898 - val_accuracy: 0.5455
# Epoch 29/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0806 - accuracy: 1.0000 - val_loss: 1.8809 - val_accuracy: 0.5455
# Epoch 30/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0682 - accuracy: 1.0000 - val_loss: 1.9368 - val_accuracy: 0.5455
# Epoch 31/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0503 - accuracy: 1.0000 - val_loss: 2.0961 - val_accuracy: 0.5455
# Epoch 32/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0383 - accuracy: 1.0000 - val_loss: 2.0281 - val_accuracy: 0.5455
# Epoch 33/250
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 2.1146 - val_accuracy: 0.5455
# Epoch 34/250
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 2.2316 - val_accuracy: 0.5455
# Epoch 35/250
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 2.2112 - val_accuracy: 0.5455
# Epoch 36/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 2.2699 - val_accuracy: 0.5455
# Epoch 37/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 2.3833 - val_accuracy: 0.5455
# Epoch 38/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 2.4161 - val_accuracy: 0.5455
# Epoch 39/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 2.3829 - val_accuracy: 0.5455
# Epoch 40/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 2.3846 - val_accuracy: 0.5455
# Epoch 41/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 2.4213 - val_accuracy: 0.5455
# Epoch 42/250
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 2.4546 - val_accuracy: 0.5455
# Epoch 43/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 2.5013 - val_accuracy: 0.5455
# Epoch 44/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 2.5290 - val_accuracy: 0.5455
# Epoch 45/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 2.5497 - val_accuracy: 0.5455
# Epoch 46/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.5768 - val_accuracy: 0.5455
# Epoch 47/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 2.6149 - val_accuracy: 0.5455
# Epoch 48/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 2.6298 - val_accuracy: 0.5455
# Epoch 49/250
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.6345 - val_accuracy: 0.5455
# Epoch 50/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.6398 - val_accuracy: 0.5455
# Epoch 51/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.6673 - val_accuracy: 0.5455
# Epoch 52/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.7061 - val_accuracy: 0.5455
# Epoch 53/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.7123 - val_accuracy: 0.5455
# Epoch 54/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.7041 - val_accuracy: 0.5455
# Epoch 55/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.6995 - val_accuracy: 0.5455
# Epoch 56/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.7075 - val_accuracy: 0.5455
# Epoch 57/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.7176 - val_accuracy: 0.5455
# Epoch 58/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.7369 - val_accuracy: 0.5455
# Epoch 59/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.7559 - val_accuracy: 0.5455
# Epoch 60/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.7733 - val_accuracy: 0.5455
# Epoch 61/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.7866 - val_accuracy: 0.5455
# Epoch 62/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.7883 - val_accuracy: 0.5455
# Epoch 63/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.7997 - val_accuracy: 0.5455
# Epoch 64/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.8019 - val_accuracy: 0.5455
# Epoch 65/250
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.8076 - val_accuracy: 0.5455
# Epoch 66/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.8213 - val_accuracy: 0.5455
# Epoch 67/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.8272 - val_accuracy: 0.5455
# Epoch 68/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.8316 - val_accuracy: 0.5455
# Epoch 69/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.8484 - val_accuracy: 0.5455
# Epoch 70/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.8610 - val_accuracy: 0.5455
# Epoch 71/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.8631 - val_accuracy: 0.5455
# Epoch 72/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.8711 - val_accuracy: 0.5455
# Epoch 73/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.8790 - val_accuracy: 0.5455
# Epoch 74/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.8891 - val_accuracy: 0.5455
# Epoch 75/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.8933 - val_accuracy: 0.5455
# Epoch 76/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.9052 - val_accuracy: 0.5455
# Epoch 77/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.9177 - val_accuracy: 0.5455
# Epoch 78/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.9266 - val_accuracy: 0.5455
# Epoch 79/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.9231 - val_accuracy: 0.5455
# Epoch 80/250
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.9266 - val_accuracy: 0.5455
# Epoch 81/250
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.9346 - val_accuracy: 0.5455
# Epoch 82/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.9473 - val_accuracy: 0.5455
# Epoch 83/250
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.9497 - val_accuracy: 0.5455
# Epoch 84/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.9590 - val_accuracy: 0.5455
# Epoch 85/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.9637 - val_accuracy: 0.5455
# Epoch 86/250
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.9742 - val_accuracy: 0.5455
# Epoch 87/250
# 3/3 [==============================] - 0s 17ms/step - loss: 9.7708e-04 - accuracy: 1.0000 - val_loss: 2.9783 - val_accuracy: 0.5455
# Epoch 88/250
# 3/3 [==============================] - 0s 17ms/step - loss: 9.5689e-04 - accuracy: 1.0000 - val_loss: 2.9834 - val_accuracy: 0.5455
# Epoch 89/250
# 3/3 [==============================] - 0s 16ms/step - loss: 9.3334e-04 - accuracy: 1.0000 - val_loss: 2.9929 - val_accuracy: 0.5455
# Epoch 90/250
# 3/3 [==============================] - 0s 19ms/step - loss: 9.1482e-04 - accuracy: 1.0000 - val_loss: 2.9981 - val_accuracy: 0.5455
# Epoch 91/250
# 3/3 [==============================] - 0s 16ms/step - loss: 8.9555e-04 - accuracy: 1.0000 - val_loss: 3.0038 - val_accuracy: 0.5455
# Epoch 92/250
# 3/3 [==============================] - 0s 17ms/step - loss: 3.2592e-04 - accuracy: 1.0000 - val_loss: 3.2692 - val_accuracy: 0.5455
# Epoch 150/250
# 3/3 [==============================] - 0s 17ms/step - loss: 3.2126e-04 - accuracy: 1.0000 - val_loss: 3.2762 - val_accuracy: 0.5455
# Epoch 151/250
# 3/3 [==============================] - 0s 17ms/step - loss: 3.1704e-04 - accuracy: 1.0000 - val_loss: 3.2818 - val_accuracy: 0.5455
# Epoch 152/250
# 3/3 [==============================] - 0s 16ms/step - loss: 3.1349e-04 - accuracy: 1.0000 - val_loss: 3.2817 - val_accuracy: 0.5455
# Epoch 153/250
# 3/3 [==============================] - 0s 16ms/step - loss: 3.0877e-04 - accuracy: 1.0000 - val_loss: 3.2823 - val_accuracy: 0.5455
# Epoch 154/250
# 3/3 [==============================] - 0s 18ms/step - loss: 3.0498e-04 - accuracy: 1.0000 - val_loss: 3.2829 - val_accuracy: 0.5455
# Epoch 155/250
# 3/3 [==============================] - 0s 17ms/step - loss: 3.0059e-04 - accuracy: 1.0000 - val_loss: 3.2869 - val_accuracy: 0.5455
# Epoch 156/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.9762e-04 - accuracy: 1.0000 - val_loss: 3.2955 - val_accuracy: 0.5455
# Epoch 157/250
# 3/3 [==============================] - 0s 16ms/step - loss: 2.9273e-04 - accuracy: 1.0000 - val_loss: 3.2965 - val_accuracy: 0.5455
# Epoch 158/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.8859e-04 - accuracy: 1.0000 - val_loss: 3.3001 - val_accuracy: 0.5455
# Epoch 159/250
# 3/3 [==============================] - 0s 19ms/step - loss: 2.8522e-04 - accuracy: 1.0000 - val_loss: 3.3036 - val_accuracy: 0.5455
# Epoch 160/250
# 3/3 [==============================] - 0s 16ms/step - loss: 2.8188e-04 - accuracy: 1.0000 - val_loss: 3.3080 - val_accuracy: 0.5455
# Epoch 161/250
# 3/3 [==============================] - 0s 16ms/step - loss: 2.7847e-04 - accuracy: 1.0000 - val_loss: 3.3082 - val_accuracy: 0.5455
# Epoch 162/250
# 3/3 [==============================] - 0s 18ms/step - loss: 2.7467e-04 - accuracy: 1.0000 - val_loss: 3.3115 - val_accuracy: 0.5455
# Epoch 163/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7084e-04 - accuracy: 1.0000 - val_loss: 3.3154 - val_accuracy: 0.5455
# Epoch 164/250
# 3/3 [==============================] - 0s 18ms/step - loss: 2.6806e-04 - accuracy: 1.0000 - val_loss: 3.3215 - val_accuracy: 0.5455
# Epoch 165/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6393e-04 - accuracy: 1.0000 - val_loss: 3.3232 - val_accuracy: 0.5455
# Epoch 166/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.6352e-04 - accuracy: 1.0000 - val_loss: 3.3229 - val_accuracy: 0.5455
# Epoch 167/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.5921e-04 - accuracy: 1.0000 - val_loss: 3.3281 - val_accuracy: 0.5455
# Epoch 168/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.5466e-04 - accuracy: 1.0000 - val_loss: 3.3304 - val_accuracy: 0.5455
# Epoch 169/250
# 3/3 [==============================] - 0s 16ms/step - loss: 2.5161e-04 - accuracy: 1.0000 - val_loss: 3.3362 - val_accuracy: 0.5455
# Epoch 170/250
# 3/3 [==============================] - 0s 18ms/step - loss: 2.4891e-04 - accuracy: 1.0000 - val_loss: 3.3440 - val_accuracy: 0.5455
# Epoch 171/250
# 3/3 [==============================] - 0s 18ms/step - loss: 2.4593e-04 - accuracy: 1.0000 - val_loss: 3.3450 - val_accuracy: 0.5455
# Epoch 172/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.4235e-04 - accuracy: 1.0000 - val_loss: 3.3462 - val_accuracy: 0.5455
# Epoch 173/250
# 3/3 [==============================] - 0s 19ms/step - loss: 2.3970e-04 - accuracy: 1.0000 - val_loss: 3.3498 - val_accuracy: 0.5455
# Epoch 174/250
# 3/3 [==============================] - 0s 19ms/step - loss: 2.3705e-04 - accuracy: 1.0000 - val_loss: 3.3493 - val_accuracy: 0.5455
# Epoch 175/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.3482e-04 - accuracy: 1.0000 - val_loss: 3.3564 - val_accuracy: 0.5455
# Epoch 176/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.3143e-04 - accuracy: 1.0000 - val_loss: 3.3562 - val_accuracy: 0.5455
# Epoch 177/250
# 3/3 [==============================] - 0s 19ms/step - loss: 2.2892e-04 - accuracy: 1.0000 - val_loss: 3.3594 - val_accuracy: 0.5455
# Epoch 178/250
# 3/3 [==============================] - 0s 18ms/step - loss: 2.2634e-04 - accuracy: 1.0000 - val_loss: 3.3592 - val_accuracy: 0.5455
# Epoch 179/250
# 3/3 [==============================] - 0s 18ms/step - loss: 2.2404e-04 - accuracy: 1.0000 - val_loss: 3.3607 - val_accuracy: 0.5455
# Epoch 180/250
# 3/3 [==============================] - 0s 18ms/step - loss: 2.2107e-04 - accuracy: 1.0000 - val_loss: 3.3713 - val_accuracy: 0.5455
# Epoch 181/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.1872e-04 - accuracy: 1.0000 - val_loss: 3.3800 - val_accuracy: 0.5455
# Epoch 182/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.1614e-04 - accuracy: 1.0000 - val_loss: 3.3817 - val_accuracy: 0.5455
# Epoch 183/250
# 3/3 [==============================] - 0s 18ms/step - loss: 2.1348e-04 - accuracy: 1.0000 - val_loss: 3.3828 - val_accuracy: 0.5455
# Epoch 184/250
# 3/3 [==============================] - 0s 18ms/step - loss: 2.1153e-04 - accuracy: 1.0000 - val_loss: 3.3803 - val_accuracy: 0.5455
# Epoch 185/250
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0993e-04 - accuracy: 1.0000 - val_loss: 3.3861 - val_accuracy: 0.5455
# Epoch 186/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.0694e-04 - accuracy: 1.0000 - val_loss: 3.3889 - val_accuracy: 0.5455
# Epoch 187/250
# 3/3 [==============================] - 0s 16ms/step - loss: 2.0464e-04 - accuracy: 1.0000 - val_loss: 3.3879 - val_accuracy: 0.5455
# Epoch 188/250
# 3/3 [==============================] - 0s 17ms/step - loss: 2.0236e-04 - accuracy: 1.0000 - val_loss: 3.3928 - val_accuracy: 0.5455
# Epoch 189/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.9976e-04 - accuracy: 1.0000 - val_loss: 3.3953 - val_accuracy: 0.5455
# Epoch 190/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.9754e-04 - accuracy: 1.0000 - val_loss: 3.3964 - val_accuracy: 0.5455
# Epoch 191/250
# 3/3 [==============================] - 0s 16ms/step - loss: 1.9566e-04 - accuracy: 1.0000 - val_loss: 3.3993 - val_accuracy: 0.5455
# Epoch 192/250
# 3/3 [==============================] - 0s 16ms/step - loss: 1.9356e-04 - accuracy: 1.0000 - val_loss: 3.4036 - val_accuracy: 0.5455
# Epoch 193/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.9167e-04 - accuracy: 1.0000 - val_loss: 3.4097 - val_accuracy: 0.5455
# Epoch 194/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8984e-04 - accuracy: 1.0000 - val_loss: 3.4129 - val_accuracy: 0.5455
# Epoch 195/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8767e-04 - accuracy: 1.0000 - val_loss: 3.4144 - val_accuracy: 0.5455
# Epoch 196/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8585e-04 - accuracy: 1.0000 - val_loss: 3.4112 - val_accuracy: 0.5455
# Epoch 197/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.8372e-04 - accuracy: 1.0000 - val_loss: 3.4164 - val_accuracy: 0.5455
# Epoch 198/250
# 3/3 [==============================] - 0s 16ms/step - loss: 1.8167e-04 - accuracy: 1.0000 - val_loss: 3.4223 - val_accuracy: 0.5455
# Epoch 199/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8072e-04 - accuracy: 1.0000 - val_loss: 3.4279 - val_accuracy: 0.5455
# Epoch 200/250
# 3/3 [==============================] - 0s 19ms/step - loss: 1.7842e-04 - accuracy: 1.0000 - val_loss: 3.4306 - val_accuracy: 0.5455
# Epoch 201/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.7678e-04 - accuracy: 1.0000 - val_loss: 3.4272 - val_accuracy: 0.5455
# Epoch 202/250
# 3/3 [==============================] - 0s 16ms/step - loss: 1.7464e-04 - accuracy: 1.0000 - val_loss: 3.4292 - val_accuracy: 0.5455
# Epoch 203/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.7274e-04 - accuracy: 1.0000 - val_loss: 3.4357 - val_accuracy: 0.5455
# Epoch 204/250
# 3/3 [==============================] - 0s 19ms/step - loss: 1.7146e-04 - accuracy: 1.0000 - val_loss: 3.4443 - val_accuracy: 0.5455
# Epoch 205/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.6937e-04 - accuracy: 1.0000 - val_loss: 3.4442 - val_accuracy: 0.5455
# Epoch 206/250
# 3/3 [==============================] - 0s 16ms/step - loss: 1.6770e-04 - accuracy: 1.0000 - val_loss: 3.4477 - val_accuracy: 0.5455
# Epoch 207/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.6592e-04 - accuracy: 1.0000 - val_loss: 3.4501 - val_accuracy: 0.5455
# Epoch 208/250
# 3/3 [==============================] - 0s 16ms/step - loss: 1.6453e-04 - accuracy: 1.0000 - val_loss: 3.4483 - val_accuracy: 0.5455
# Epoch 209/250
# 3/3 [==============================] - 0s 16ms/step - loss: 1.6270e-04 - accuracy: 1.0000 - val_loss: 3.4502 - val_accuracy: 0.5455
# Epoch 210/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.6110e-04 - accuracy: 1.0000 - val_loss: 3.4552 - val_accuracy: 0.5455
# Epoch 211/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.5947e-04 - accuracy: 1.0000 - val_loss: 3.4569 - val_accuracy: 0.5455
# Epoch 212/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.5781e-04 - accuracy: 1.0000 - val_loss: 3.4580 - val_accuracy: 0.5455
# Epoch 213/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.5621e-04 - accuracy: 1.0000 - val_loss: 3.4623 - val_accuracy: 0.5455
# Epoch 214/250
# 3/3 [==============================] - 0s 19ms/step - loss: 1.5483e-04 - accuracy: 1.0000 - val_loss: 3.4661 - val_accuracy: 0.5455
# Epoch 215/250
# 3/3 [==============================] - 0s 19ms/step - loss: 1.5329e-04 - accuracy: 1.0000 - val_loss: 3.4721 - val_accuracy: 0.5455
# Epoch 216/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.5176e-04 - accuracy: 1.0000 - val_loss: 3.4734 - val_accuracy: 0.5455
# Epoch 217/250
# 3/3 [==============================] - 0s 16ms/step - loss: 1.5057e-04 - accuracy: 1.0000 - val_loss: 3.4739 - val_accuracy: 0.5455
# Epoch 218/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.4914e-04 - accuracy: 1.0000 - val_loss: 3.4766 - val_accuracy: 0.5455
# Epoch 219/250
# 3/3 [==============================] - 0s 20ms/step - loss: 1.4770e-04 - accuracy: 1.0000 - val_loss: 3.4759 - val_accuracy: 0.5455
# Epoch 220/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.4628e-04 - accuracy: 1.0000 - val_loss: 3.4784 - val_accuracy: 0.5455
# Epoch 221/250
# 3/3 [==============================] - 0s 16ms/step - loss: 1.4483e-04 - accuracy: 1.0000 - val_loss: 3.4815 - val_accuracy: 0.5455
# Epoch 222/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.4353e-04 - accuracy: 1.0000 - val_loss: 3.4839 - val_accuracy: 0.5455
# Epoch 223/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.4212e-04 - accuracy: 1.0000 - val_loss: 3.4861 - val_accuracy: 0.5455
# Epoch 224/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.4072e-04 - accuracy: 1.0000 - val_loss: 3.4901 - val_accuracy: 0.5455
# Epoch 225/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3939e-04 - accuracy: 1.0000 - val_loss: 3.4913 - val_accuracy: 0.5455
# Epoch 226/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3820e-04 - accuracy: 1.0000 - val_loss: 3.4973 - val_accuracy: 0.5455
# Epoch 227/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3714e-04 - accuracy: 1.0000 - val_loss: 3.5018 - val_accuracy: 0.5455
# Epoch 228/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3573e-04 - accuracy: 1.0000 - val_loss: 3.5014 - val_accuracy: 0.5455
# Epoch 229/250
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3439e-04 - accuracy: 1.0000 - val_loss: 3.5018 - val_accuracy: 0.5455
# Epoch 230/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3332e-04 - accuracy: 1.0000 - val_loss: 3.5034 - val_accuracy: 0.5455
# Epoch 231/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3198e-04 - accuracy: 1.0000 - val_loss: 3.5079 - val_accuracy: 0.5455
# Epoch 232/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3092e-04 - accuracy: 1.0000 - val_loss: 3.5097 - val_accuracy: 0.5455
# Epoch 233/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2975e-04 - accuracy: 1.0000 - val_loss: 3.5105 - val_accuracy: 0.5455
# Epoch 234/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2867e-04 - accuracy: 1.0000 - val_loss: 3.5111 - val_accuracy: 0.5455
# Epoch 235/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2769e-04 - accuracy: 1.0000 - val_loss: 3.5166 - val_accuracy: 0.5455
# Epoch 236/250
# 3/3 [==============================] - 0s 19ms/step - loss: 1.2624e-04 - accuracy: 1.0000 - val_loss: 3.5183 - val_accuracy: 0.5455
# Epoch 237/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2512e-04 - accuracy: 1.0000 - val_loss: 3.5196 - val_accuracy: 0.5455
# Epoch 238/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2397e-04 - accuracy: 1.0000 - val_loss: 3.5224 - val_accuracy: 0.5455
# Epoch 239/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2297e-04 - accuracy: 1.0000 - val_loss: 3.5273 - val_accuracy: 0.5455
# Epoch 240/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2192e-04 - accuracy: 1.0000 - val_loss: 3.5262 - val_accuracy: 0.5455
# Epoch 241/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2086e-04 - accuracy: 1.0000 - val_loss: 3.5295 - val_accuracy: 0.5455
# Epoch 242/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1971e-04 - accuracy: 1.0000 - val_loss: 3.5327 - val_accuracy: 0.5455
# Epoch 243/250
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1858e-04 - accuracy: 1.0000 - val_loss: 3.5317 - val_accuracy: 0.5455
# Epoch 244/250
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1778e-04 - accuracy: 1.0000 - val_loss: 3.5313 - val_accuracy: 0.5455
# Epoch 245/250
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1652e-04 - accuracy: 1.0000 - val_loss: 3.5335 - val_accuracy: 0.5455
# Epoch 246/250
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1553e-04 - accuracy: 1.0000 - val_loss: 3.5360 - val_accuracy: 0.5455
# Epoch 247/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1463e-04 - accuracy: 1.0000 - val_loss: 3.5383 - val_accuracy: 0.5455
# Epoch 248/250
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1374e-04 - accuracy: 1.0000 - val_loss: 3.5384 - val_accuracy: 0.5455
# Epoch 249/250
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1268e-04 - accuracy: 1.0000 - val_loss: 3.5449 - val_accuracy: 0.5455
# Epoch 250/250
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1175e-04 - accuracy: 1.0000 - val_loss: 3.5485 - val_accuracy: 0.5455
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, esDAimag, clases_map):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # asigna el nombre de la clase real
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        # asigna el nombre de la clase predecida
        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA!"
        else:      
            clPred = clases_map[ idclPredRnd ]

        # agrega a vevtores auxiliares
        classReal.append( clReal )
        classPreds.append( clPred )

        # sólo muestra las imágenes no generadas por DA
        if not esDAimag[i]:
          strTitulo = 'Real: ' + clReal + ' / RNA: ' 
          strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'    

          # muestra comparación con la imagen
          fig = plt.figure()
          fig.suptitle( strTitulo )
          ax1 = fig.add_subplot(121)
          plot_image( x[i] )
          
          plt.tight_layout()
          fig = plt.gcf()

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    print(cmtx)
    print("\n")

    print("\n>Resultados: ")


# prueba con los datos de prueba
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, esDAimag_train, clases_map)
# Out:
# *** Resultados con datos de Entrenamiento:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:45: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#          ave       0.89      0.94      0.91        17
#      insecto       0.94      0.94      0.94        17
# invertebrado       1.00      0.94      0.97        17
#     mamifero       1.00      1.00      1.00        17
#          pez       0.94      1.00      0.97        17
#       reptil       0.94      0.88      0.91        17
#
#     accuracy                           0.95       102
#    macro avg       0.95      0.95      0.95       102
# weighted avg       0.95      0.95      0.95       102
#
#
# Matriz de Confusión:
#                 p:ave  p:reptil  p:mamifero  p:invertebrado  p:insecto  p:pez
# r:ave              16         1           0               0          0      0
# r:reptil            1        15           0               0          0      1
# r:mamifero          0         0          17               0          0      0
# r:invertebrado      0         0           0              16          1      0
# r:insecto           1         0           0               0         16      0
# r:pez               0         0           0               0          0     17
#
#
#
# >Resultados:

# %% [markdown]
# 7) Evaluar el modelo de la RNA entrenado usando las imágenes de prueba:

# %%
#@title Probar red entrenada con datos de prueba
 # evalua al modelo entrenado
resEval = model.evaluate(x_test, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de entrenamiento
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(x_test, y_test, esDAimag_test, clases_map)
# Out:
# 2/2 [==============================] - 0s 47ms/step - loss: 3.8757 - accuracy: 0.6167
#
# >Evaluación del Modelo:
#     - Error:  3.875650644302368
#     - Exactitud:  61.666667461395264
#
#
#
#
# *** Resultados con datos de Prueba:
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#          ave       0.50      0.70      0.58        10
#      insecto       0.86      0.60      0.71        10
# invertebrado       0.60      0.60      0.60        10
#     mamifero       0.70      0.70      0.70        10
#          pez       0.60      0.60      0.60        10
#       reptil       0.56      0.50      0.53        10
#
#     accuracy                           0.62        60
#    macro avg       0.64      0.62      0.62        60
# weighted avg       0.64      0.62      0.62        60
#
#
# Matriz de Confusión:
#                 p:ave  p:reptil  p:mamifero  p:invertebrado  p:insecto  p:pez
# r:ave               7         1           0               0          1      1
# r:reptil            0         5           2               2          0      1
# r:mamifero          1         1           7               1          0      0
# r:invertebrado      1         1           1               6          0      1
# r:insecto           2         0           0               1          6      1
# r:pez               3         1           0               0          0      6
#
#
#
# >Resultados:
