# %% [markdown]
# # Demo Convolutional Neural Network (CNN) para procesar imágenes e identificar TIPOS de ANIMALES

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
import keras
from keras.layers import Input, Dense
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Reshape, Flatten, Dropout
from keras.models import Model
from keras.utils import plot_model

from sklearn.model_selection import train_test_split
from keras.utils import np_utils

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Definir los parámetros:

# %%
## selección de los parámetros 

# 
#@markdown ### Parámetros de imágenes:
imagen_largo_ancho =  64#@param {type:"integer"}
imagen_color = True #@param {type:"boolean"}
imagen_usar_generadas_data_augmentation = True #@param {type:"boolean"}

#@markdown ### Parámetros de la red:
cnn_tamaño_kernel = 5 #@param {type:"integer"}
cnn_tamaño_pooling = 3 #@param {type:"integer"}
cnn_cantidad_capas_ocultas = 3 #@param {type:"integer"}
cnn_cantidad_neuronas_Dense = 32 #@param {type:"integer"}
cnn_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
cnn_cant_epocas_entrenamiento =  150#@param {type:"integer"}


## aplicación de los parámetros elegidos

# tamaño de las imágenes
if imagen_largo_ancho<=10:
  imagen_largo_ancho = 10
IMAGE_SHAPE = (imagen_largo_ancho, imagen_largo_ancho, (3 if imagen_color else 1))

# indica si se usan las imágenes generadas por data augmentation
usarDA = imagen_usar_generadas_data_augmentation

# tamaño de los kernels y pooling (para simplificar son todas iguales)
if cnn_tamaño_kernel<1:
  cnn_tamaño_kernel = 1
cnn_kernel_shape = (cnn_tamaño_kernel, cnn_tamaño_kernel)
if cnn_tamaño_pooling<1:
  cnn_tamaño_pooling=1
cnn_pooling_shape = (cnn_tamaño_pooling, cnn_tamaño_pooling)

# indica la configuración para la parte Encoder 
#   (cada elemento de las listas son la configuración de las capas Conv)
#cnn_filters = [ 128, 64, 32, 16, 8 ] 
if cnn_cantidad_capas_ocultas<1:
  cnn_cantidad_capas_ocultas = 1
cnn_filters = []
for i in range(cnn_cantidad_capas_ocultas, 0, -1):
  cnn_filters.append( 2**(i+2) )

# define tamaño de capa densa previa a la de salida
num_Dense_out = (8 if cnn_cantidad_neuronas_Dense<1 else cnn_cantidad_neuronas_Dense)

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (cnn_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if cnn_cant_epocas_entrenamiento<1 else cnn_cant_epocas_entrenamiento)

print("Configuración de la CNN definida: ")
print ("     -Tamaño Imagen: ", IMAGE_SHAPE)
print ("     -Kernels + Pooling: [", cnn_kernel_shape, "+", cnn_pooling_shape, "] ")
print ("     -Capas: [ ", IMAGE_SHAPE, ", Conv", cnn_filters,  ", FLATTEN, Dense[", num_Dense_out, "], DROP-OUT, ", ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Configuración de la CNN definida:
#      -Tamaño Imagen:  (64, 64, 3)
#      -Kernels + Pooling: [ (5, 5) + (3, 3) ]
#      -Capas: [  (64, 64, 3) , Conv [32, 16, 8] , FLATTEN, Dense[ 32 ], DROP-OUT,  Softmax

# %% [markdown]
# 3) Montar el Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/IA/demo ANIMALES/imagenes' #@param {type:"string"}
path_entrenamiento = '/train'  #@param {type:"string"}
path_prueba = '/test'  #@param {type:"string"}

imagPath_train = path + path_entrenamiento
imagPath_test = path + path_prueba
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo:

# %%
#@title Cargar imágenes
# define función para cargar las imágenes
def cargarImagenes(imagPath):
  classes_ori = [] 
  images_ori = []
  esDA_ori = []

  all_dirs = os.listdir( imagPath )
  for each_dir in all_dirs:

      auxiPath = imagPath + '/' + each_dir 
      imagFN  = os.listdir( auxiPath )
      for each_imagFN in imagFN:

            esImagDA = (each_imagFN[:2] == 'da')
            
            if usarDA or (not esImagDA): 
                
                # abre la imagen
                imag = Image.open(auxiPath + "/" + each_imagFN)
                
                # ajusta el tamaño
                if IMAGE_SHAPE[2]==1:              
                  tipoImage = 'L'
                else:                
                  tipoImage = 'RGB'
                imag = imag.convert(tipoImage)
                imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.ANTIALIAS)          
                
                # transforma a un vector de nros
                arImag = np.array(imag)
                
                # agrega a los vectores
                classes_ori.append( each_dir )
                images_ori.append( arImag )
                esDA_ori.append( esImagDA )

  return classes_ori, images_ori, esDA_ori, tipoImage

# carga las imagenes de entrenamiento
classes_train, images_train, esDAimag_train, tipoImage_train = cargarImagenes(imagPath_train)
print("> Para Entrenamiento: ")
print("- Clases cargadas: ", len(classes_train))
print("- Imágenes cargadas: ", len(classes_train))

if len(classes_train)>0:
  print("- Ejemplo ", classes_train[0], " ", images_train[0].shape, ": ")
  display( Image.fromarray(images_train[0], tipoImage_train) )

# carga las imagenes de prueba
classes_test, images_test, esDAimag_test, tipoImage_test = cargarImagenes(imagPath_test)
print("\n\n> Para Prueba: ")
print("- Clases cargadas: ", len(classes_test))
print("- Imágenes cargadas: ", len(images_test))

if len(classes_test)>0:
  print("- Ejemplo ", classes_test[0], " ", images_test[0].shape, ": ")
  display( Image.fromarray(images_test[0], tipoImage_test) )
# Out:
# > Para Entrenamiento:
# - Clases cargadas:  102
# - Imágenes cargadas:  102
# - Ejemplo  ave   (64, 64, 3) :
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F9948F945F8>
# > Para Prueba:
# - Clases cargadas:  60
# - Imágenes cargadas:  60
# - Ejemplo  invertebrado   (64, 64, 3) :
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F9948F94C18>

# %%
#@title Preparar imágenes
# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8))
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):    
  auxiAr = np.array(imagList).astype('float32') / 255.
  auxiAr = auxiAr.reshape((len(auxiAr), IMAGE_SHAPE[0], IMAGE_SHAPE[1], IMAGE_SHAPE[2]))  
  return auxiAr
  
# define función auxiliar para preparar lista de clases 
def prepare_clasesList(classesList, dictMapeo=None):
  if dictMapeo==None:
    # genera diccionario de mapeo
    auxDict = list(set(classesList))
    dictMapeo = dict( zip( auxDict, range(len(auxDict)) ) )
  # realiza el mapeo
  y = []
  for cl in classesList:
      y.append( dictMapeo[cl] )
  # convierte valores numéricos a columnas de vakores binarios (i.e. one hot encoded)
  dummy_y = np_utils.to_categorical(y)
  # devuelve
  return np.array(y), np.array(dummy_y), dictMapeo

# define vector auxiliar de datos de entrada para usar en el entrenamiento y prueba
x_train = prepare_imageList(images_train)
x_test = prepare_imageList(images_test)

# define vector auxiliar de datos de salida para usar en el entrenamiento y prueba
# también usa esta información para determinar la cantida de neuronas de salida
y_train, y_trainEnc, dictMapeo = prepare_clasesList(classes_train)
y_test, y_testEnc,_ = prepare_clasesList(classes_test, dictMapeo)

# genera diccionario auxiliar para poder convertir de ID de clase a nombre de clase
clases_map = [ x for x,y in dictMapeo.items() ]

print("> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
if tipo_output_softMax:
  print(" - y_trainEnc (cant): ", len(y_trainEnc))
else:
  print(" - y_train (cant): ", len(y_train))
print("\n\n> Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
if tipo_output_softMax:
  print(" - y_testEnc (cant): ", len(y_testEnc))
else:
  print(" - y_test (cant): ", len(y_test))
print("\n\n> Para Ambos: ")
print(" - dictMapeo: ", dictMapeo)
print(" - clases_map: ", clases_map)
if len(y_train)>0:
  print("\n - Imagen reconstruida de ", clases_map[y_train[0]],  "(", y_train[0], " / ", y_trainEnc[0], ")")
  plot_image(x_train[0])
# Out:
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (102, 64, 64, 3)
#  - y_trainEnc (cant):  102
#
#
# > Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (60, 64, 64, 3)
#  - y_testEnc (cant):  60
#
#
# > Para Ambos:
#  - dictMapeo:  {'invertebrado': 0, 'ave': 1, 'insecto': 2, 'mamifero': 3, 'pez': 4, 'reptil': 5}
#  - clases_map:  ['invertebrado', 'ave', 'insecto', 'mamifero', 'pez', 'reptil']
#
#  - Imagen reconstruida de  ave ( 1  /  [0. 1. 0. 0. 0. 0.] )

# %% [markdown]
# 5) Establecer el modelo para la CNN:

# %%
#@title Establecer modelo

# define la arquitectura de capas de la CNN
# teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=IMAGE_SHAPE, name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'conv_'
for i in range(len(cnn_filters)):  

    # define el nombre de la capa oculta
    auxlayerName = 'conv_'+str(i+1)

    # agrega las capas ocultas de tipo Conv2D + MaxPooling 
    eachLay = Conv2D(cnn_filters[i], cnn_kernel_shape, activation='relu', padding='same', name='c_'+auxlayerName)(eachLay) 
    eachLay = MaxPooling2D(cnn_pooling_shape, padding='same', name='p_'+auxlayerName)(eachLay)

#  agrega capa Flatten y Dense 
eachLay = Flatten(name='flat_'+auxlayerName)(eachLay)
eachLay = Dense(num_Dense_out, activation='relu', name='d_'+auxlayerName)(eachLay)
eachLay = Dropout(0.5)(eachLay)

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(dictMapeo), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida

# genera el modelo Deep Autoencoder
model = Model(input_img_Lay, output_img_Lay, name='ConvNet')
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

print("Modelo CNN creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo CNN creado con  11  capas:
# Model: "ConvNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_img (InputLayer)       [(None, 64, 64, 3)]       0
# _________________________________________________________________
# c_conv_1 (Conv2D)            (None, 64, 64, 32)        2432
# _________________________________________________________________
# p_conv_1 (MaxPooling2D)      (None, 22, 22, 32)        0
# _________________________________________________________________
# c_conv_2 (Conv2D)            (None, 22, 22, 16)        12816
# _________________________________________________________________
# p_conv_2 (MaxPooling2D)      (None, 8, 8, 16)          0
# _________________________________________________________________
# c_conv_3 (Conv2D)            (None, 8, 8, 8)           3208
# _________________________________________________________________
# p_conv_3 (MaxPooling2D)      (None, 3, 3, 8)           0
# _________________________________________________________________
# flat_conv_3 (Flatten)        (None, 72)                0
# _________________________________________________________________
# d_conv_3 (Dense)             (None, 32)                2336
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# output (Dense)               (None, 6)                 198
# =================================================================
# Total params: 20,990
# Trainable params: 20,990
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 6) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(x_train, 
                                       (y_trainEnc if 

tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,) ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  102 ejemplos de entrenamiento:
#             se usan  91 ejemplos para entrenar
#             y  11 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/150
# 3/3 [==============================] - 0s 94ms/step - loss: 1.8511 - accuracy: 0.1099 - val_loss: 1.7390 - val_accuracy: 0.2727
# Epoch 2/150
# 3/3 [==============================] - 0s 9ms/step - loss: 1.7650 - accuracy: 0.2088 - val_loss: 1.7742 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 3/3 [==============================] - 0s 9ms/step - loss: 1.7922 - accuracy: 0.1868 - val_loss: 1.7779 - val_accuracy: 0.0909
# Epoch 4/150
# 3/3 [==============================] - 0s 9ms/step - loss: 1.7847 - accuracy: 0.2198 - val_loss: 1.7766 - val_accuracy: 0.0909
# Epoch 5/150
# 3/3 [==============================] - 0s 10ms/step - loss: 1.7862 - accuracy: 0.2088 - val_loss: 1.7847 - val_accuracy: 0.1818
# Epoch 6/150
# 3/3 [==============================] - 0s 10ms/step - loss: 1.7604 - accuracy: 0.2637 - val_loss: 1.7844 - val_accuracy: 0.1818
# Epoch 7/150
# 3/3 [==============================] - 0s 9ms/step - loss: 1.7507 - accuracy: 0.2967 - val_loss: 1.7792 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7572 - accuracy: 0.2088 - val_loss: 1.7737 - val_accuracy: 0.0909
# Epoch 9/150
# 3/3 [==============================] - 0s 9ms/step - loss: 1.7422 - accuracy: 0.2088 - val_loss: 1.7735 - val_accuracy: 0.2727
# Epoch 10/150
# 3/3 [==============================] - 0s 9ms/step - loss: 1.7410 - accuracy: 0.2308 - val_loss: 1.7564 - val_accuracy: 0.2727
# Epoch 11/150
# 3/3 [==============================] - 0s 11ms/step - loss: 1.7058 - accuracy: 0.3077 - val_loss: 1.7537 - val_accuracy: 0.2727
# Epoch 12/150
# 3/3 [==============================] - 0s 10ms/step - loss: 1.6803 - accuracy: 0.3297 - val_loss: 1.7403 - val_accuracy: 0.2727
# Epoch 13/150
# 3/3 [==============================] - 0s 10ms/step - loss: 1.6601 - accuracy: 0.3846 - val_loss: 1.7357 - val_accuracy: 0.2727
# Epoch 14/150
# 3/3 [==============================] - 0s 9ms/step - loss: 1.6461 - accuracy: 0.3736 - val_loss: 1.7365 - val_accuracy: 0.3636
# Epoch 15/150
# 3/3 [==============================] - 0s 9ms/step - loss: 1
150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2440 - accuracy: 0.9231 - val_loss: 1.6324 - val_accuracy: 0.3636
# Epoch 73/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2615 - accuracy: 0.9011 - val_loss: 1.5798 - val_accuracy: 0.4545
# Epoch 74/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2539 - accuracy: 0.9560 - val_loss: 1.5357 - val_accuracy: 0.4545
# Epoch 75/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2457 - accuracy: 0.9121 - val_loss: 1.4685 - val_accuracy: 0.3636
# Epoch 76/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2765 - accuracy: 0.9121 - val_loss: 1.3909 - val_accuracy: 0.4545
# Epoch 77/150
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2120 - accuracy: 0.9341 - val_loss: 1.4337 - val_accuracy: 0.4545
# Epoch 78/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2476 - accuracy: 0.8791 - val_loss: 1.4964 - val_accuracy: 0.4545
# Epoch 79/150
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2150 - accuracy: 0.9451 - val_loss: 1.5893 - val_accuracy: 0.4545
# Epoch 80/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1841 - accuracy: 0.9451 - val_loss: 1.5789 - val_accuracy: 0.3636
# Epoch 81/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2231 - accuracy: 0.9231 - val_loss: 1.5467 - val_accuracy: 0.4545
# Epoch 82/150
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1864 - accuracy: 0.9560 - val_loss: 1.5387 - val_accuracy: 0.4545
# Epoch 83/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2273 - accuracy: 0.9451 - val_loss: 1.5763 - val_accuracy: 0.4545
# Epoch 84/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2788 - accuracy: 0.9011 - val_loss: 1.6224 - val_accuracy: 0.4545
# Epoch 85/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1729 - accuracy: 0.9451 - val_loss: 1.5230 - val_accuracy: 0.4545
# Epoch 86/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2938 - accuracy: 0.9011 - val_loss: 1.4866 - val_accuracy: 0.4545
# Epoch 87/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2521 - accuracy: 0.9011 - val_loss: 1.6699 - val_accuracy: 0.4545
# Epoch 88/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2570 - accuracy: 0.9011 - val_loss: 1.8537 - val_accuracy: 0.3636
# Epoch 89/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2033 - accuracy: 0.9231 - val_loss: 1.7222 - val_accuracy: 0.3636
# Epoch 90/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2066 - accuracy: 0.9341 - val_loss: 1.5460 - val_accuracy: 0.4545
# Epoch 91/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2165 - accuracy: 0.9341 - val_loss: 1.3528 - val_accuracy: 0.4545
# Epoch 92/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2295 - accuracy: 0.9451 - val_loss: 1.4704 - val_accuracy: 0.3636
# Epoch 93/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1853 - accuracy: 0.9560 - val_loss: 1.5662 - val_accuracy: 0.3636
# Epoch 94/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1643 - accuracy: 0.9560 - val_loss: 1.4066 - val_accuracy: 0.3636
# Epoch 95/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2264 - accuracy: 0.9121 - val_loss: 1.2639 - val_accuracy: 0.5455
# Epoch 96/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1557 - accuracy: 0.9670 - val_loss: 1.3989 - val_accuracy: 0.4545
# Epoch 97/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2132 - accuracy: 0.9231 - val_loss: 1.2553 - val_accuracy: 0.4545
# Epoch 98/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1160 - accuracy: 0.9670 - val_loss: 1.3900 - val_accuracy: 0.4545
# Epoch 99/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2353 - accuracy: 0.9231 - val_loss: 1.4818 - val_accuracy: 0.4545
# Epoch 100/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1202 - accuracy: 0.9780 - val_loss: 1.5888 - val_accuracy: 0.4545
# Epoch 101/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1428 - accuracy: 0.9670 - val_loss: 1.6277 - val_accuracy: 0.4545
# Epoch 102/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1784 - accuracy: 0.9451 - val_loss: 1.7073 - val_accuracy: 0.4545
# Epoch 103/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1423 - accuracy: 0.9341 - val_loss: 1.8245 - val_accuracy: 0.4545
# Epoch 104/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1042 - accuracy: 0.9890 - val_loss: 1.7976 - val_accuracy: 0.4545
# Epoch 105/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0856 - accuracy: 0.9890 - val_loss: 1.7436 - val_accuracy: 0.4545
# Epoch 106/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2005 - accuracy: 0.9231 - val_loss: 1.7781 - val_accuracy: 0.4545
# Epoch 107/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1743 - accuracy: 0.9231 - val_loss: 1.8287 - val_accuracy: 0.4545
# Epoch 108/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1620 - accuracy: 0.9121 - val_loss: 1.8905 - val_accuracy: 0.4545
# Epoch 109/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1707 - accuracy: 0.9231 - val_loss: 1.8934 - val_accuracy: 0.4545
# Epoch 110/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0956 - accuracy: 0.9670 - val_loss: 1.8946 - val_accuracy: 0.4545
# Epoch 111/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1788 - accuracy: 0.9121 - val_loss: 1.7087 - val_accuracy: 0.4545
# Epoch 112/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1489 - accuracy: 0.9451 - val_loss: 1.4994 - val_accuracy: 0.4545
# Epoch 113/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2034 - accuracy: 0.9231 - val_loss: 1.3946 - val_accuracy: 0.4545
# Epoch 114/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1536 - accuracy: 0.9341 - val_loss: 1.5707 - val_accuracy: 0.4545
# Epoch 115/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1427 - accuracy: 0.9341 - val_loss: 1.6833 - val_accuracy: 0.3636
# Epoch 116/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2048 - accuracy: 0.9341 - val_loss: 1.7575 - val_accuracy: 0.3636
# Epoch 117/150
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1181 - accuracy: 0.9451 - val_loss: 1.5220 - val_accuracy: 0.4545
# Epoch 118/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1319 - accuracy: 0.9451 - val_loss: 1.5308 - val_accuracy: 0.4545
# Epoch 119/150
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1220 - accuracy: 0.9560 - val_loss: 1.5689 - val_accuracy: 0.5455
# Epoch 120/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0795 - accuracy: 0.9670 - val_loss: 1.7400 - val_accuracy: 0.4545
# Epoch 121/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1017 - accuracy: 0.9670 - val_loss: 2.0529 - val_accuracy: 0.3636
# Epoch 122/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1021 - accuracy: 0.9560 - val_loss: 2.0446 - val_accuracy: 0.4545
# Epoch 123/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1355 - accuracy: 0.9670 - val_loss: 2.0299 - val_accuracy: 0.4545
# Epoch 124/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0635 - accuracy: 0.9890 - val_loss: 1.8898 - val_accuracy: 0.4545
# Epoch 125/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1171 - accuracy: 0.9560 - val_loss: 1.7788 - val_accuracy: 0.4545
# Epoch 126/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1670 - accuracy: 0.9451 - val_loss: 1.8689 - val_accuracy: 0.4545
# Epoch 127/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0703 - accuracy: 0.9780 - val_loss: 1.8058 - val_accuracy: 0.4545
# Epoch 128/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0862 - accuracy: 0.9890 - val_loss: 1.7714 - val_accuracy: 0.4545
# Epoch 129/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1854 - accuracy: 0.9011 - val_loss: 1.8798 - val_accuracy: 0.4545
# Epoch 130/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0929 - accuracy: 0.9780 - val_loss: 1.8805 - val_accuracy: 0.4545
# Epoch 131/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2541 - accuracy: 0.9231 - val_loss: 1.7745 - val_accuracy: 0.4545
# Epoch 132/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1679 - accuracy: 0.9341 - val_loss: 1.7917 - val_accuracy: 0.4545
# Epoch 133/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2146 - accuracy: 0.9011 - val_loss: 1.7647 - val_accuracy: 0.4545
# Epoch 134/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1478 - accuracy: 0.9341 - val_loss: 1.8874 - val_accuracy: 0.2727
# Epoch 135/150
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0961 - accuracy: 0.9670 - val_loss: 1.7954 - val_accuracy: 0.2727
# Epoch 136/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1786 - accuracy: 0.9231 - val_loss: 1.6891 - val_accuracy: 0.3636
# Epoch 137/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2478 - accuracy: 0.8901 - val_loss: 1.6557 - val_accuracy: 0.4545
# Epoch 138/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1540 - accuracy: 0.9451 - val_loss: 1.6317 - val_accuracy: 0.4545
# Epoch 139/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1400 - accuracy: 0.9451 - val_loss: 1.6440 - val_accuracy: 0.4545
# Epoch 140/150
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1011 - accuracy: 0.9670 - val_loss: 1.6257 - val_accuracy: 0.3636
# Epoch 141/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2091 - accuracy: 0.9231 - val_loss: 1.8753 - val_accuracy: 0.4545
# Epoch 142/150
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0715 - accuracy: 0.9890 - val_loss: 2.1489 - val_accuracy: 0.4545
# Epoch 143/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0790 - accuracy: 0.9780 - val_loss: 2.1785 - val_accuracy: 0.4545
# Epoch 144/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1422 - accuracy: 0.9560 - val_loss: 2.0927 - val_accuracy: 0.3636
# Epoch 145/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0966 - accuracy: 0.9560 - val_loss: 2.0880 - val_accuracy: 0.3636
# Epoch 146/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1096 - accuracy: 0.9451 - val_loss: 1.9281 - val_accuracy: 0.3636
# Epoch 147/150
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1148 - accuracy: 0.9670 - val_loss: 1.7858 - val_accuracy: 0.4545
# Epoch 148/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0742 - accuracy: 0.9780 - val_loss: 1.9127 - val_accuracy: 0.4545
# Epoch 149/150
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1456 - accuracy: 0.9341 - val_loss: 1.7837 - val_accuracy: 0.4545
# Epoch 150/150
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0794 - accuracy: 0.9890 - val_loss: 1.8034 - val_accuracy: 0.4545
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, esDAimag, clases_map):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # asigna el nombre de la clase real
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        # asigna el nombre de la clase predecida
        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA!"
        else:      
            clPred = clases_map[ idclPredRnd ]

        # agrega a vevtores auxiliares
        classReal.append( clReal )
        classPreds.append( clPred )

        # sólo muestra las imágenes no generadas por DA
        if not esDAimag[i]:
          strTitulo = 'Real: ' + clReal + ' / RNA: ' 
          strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'    

          # muestra comparación con la imagen
          fig = plt.figure()
          fig.suptitle( strTitulo )
          ax1 = fig.add_subplot(121)
          plot_image( x[i] )
          
          plt.tight_layout()
          fig = plt.gcf()

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    print(cmtx)
    print("\n")

    print("\n>Resultados: ")


# prueba con los datos de prueba
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, esDAimag_train, clases_map)
# Out:
# *** Resultados con datos de Entrenamiento:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:45: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#          ave       0.89      0.94      0.91        17
#      insecto       0.94      0.94      0.94        17
# invertebrado       0.94      0.94      0.94        17
#     mamifero       1.00      0.94      0.97        17
#          pez       1.00      0.88      0.94        17
#       reptil       0.89      1.00      0.94        17
#
#     accuracy                           0.94       102
#    macro avg       0.94      0.94      0.94       102
# weighted avg       0.94      0.94      0.94       102
#
#
# Matriz de Confusión:
#                 p:invertebrado  p:ave  p:insecto  p:mamifero  p:pez  p:reptil
# r:invertebrado              16      0          0           0      0         1
# r:ave                        0     16          1           0      0         0
# r:insecto                    1      0         16           0      0         0
# r:mamifero                   0      0          0          16      0         1
# r:pez                        0      2          0           0     15         0
# r:reptil                     0      0          0           0      0        17
#
#
#
# >Resultados:

# %% [markdown]
# 7) Evaluar el modelo de la RNA entrenado usando las imágenes de prueba:

# %%
#@title Probar red entrenada con datos de prueba
 # evalua al modelo entrenado
resEval = model.evaluate(x_test, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de entrenamiento
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(x_test, y_test, esDAimag_test, clases_map)
# Out:
# 2/2 [==============================] - 0s 19ms/step - loss: 1.6460 - accuracy: 0.6500
#
# >Evaluación del Modelo:
#     - Error:  1.6459619998931885
#     - Exactitud:  64.99999761581421
#
#
#
#
# *** Resultados con datos de Prueba:
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#          ave       0.56      0.50      0.53        10
#      insecto       0.67      0.60      0.63        10
# invertebrado       0.75      0.60      0.67        10
#     mamifero       0.50      0.60      0.55        10
#          pez       0.80      0.80      0.80        10
#       reptil       0.67      0.80      0.73        10
#
#     accuracy                           0.65        60
#    macro avg       0.66      0.65      0.65        60
# weighted avg       0.66      0.65      0.65        60
#
#
# Matriz de Confusión:
#                 p:invertebrado  p:ave  p:insecto  p:mamifero  p:pez  p:reptil
# r:invertebrado               6      0          1           3      0         0
# r:ave                        0      5          1           1      0         3
# r:insecto                    1      2          6           0      1         0
# r:mamifero                   1      1          1           6      0         1
# r:pez                        0      1          0           1      8         0
# r:reptil                     0      0          0           1      1         8
#
#
#
# >Resultados:
